# %% [markdown]
# Activity 4.1: List vs. Tuple: Scenario Matching

# %% [markdown]
# สิ่งที่อยากให้ทำ : สถานการณ์ต่อไปนี้ แต่ละเหตุการณ์ควรใช้ list หรือ tuple เพราะอะไร

# %% [markdown]
# 1.ข้อมูลอุณหภูมิประจำวันที่มีการบันทึกไว้ตลอดหนึ่งสัปดาห์

# %% [markdown]
# = ใช้ list เพราะข้อมูลอาจมีการแก้ไขหรือเพิ่มข้อมูลได้ เช่น บันทึกอุณหภูมิใหม่หรือแก้ไขค่าที่บันทึกผิด

# %% [markdown]
# 2.ค่าสี RGB ของเฉดสีเฉพาะเฉดหนึ่ง (เช่น สีแดงคือ (255, 0, 0))

# %% [markdown]
# = ใช้ tuple เพราะค่า RGB ของสีหนึ่ง ๆ เป็นค่าคงที่ ไม่ควรเปลี่ยนแปลง

# %% [markdown]
# 3.รายการสินค้าในรถเข็นชอปปิงที่สามารถกดเพิ่มหรือลบออกได้

# %% [markdown]
# = ใช้ list เพราะสามารถเพิ่ม ลบ หรือแก้ไขรายการสินค้าได้ตลอดเวลา

# %% [markdown]
# 4.รายชื่อวันในหนึ่งสัปดาห์เรียงตามลำดับ (จันทร์ - อาทิตย์)

# %% [markdown]
# = ใช้ tuple เพราะลำดับและชื่อวันเป็นข้อมูลคงที่ ไม่เปลี่ยนแปลง

# %% [markdown]
# 5.คะแนนเก็บของนักเรียนจากการส่งงานชุดต่างๆ ซึ่งอาจมีการอัปเดตหรือแก้ไขคะแนนในภายหลังได้

# %% [markdown]
# = ใช้ list เพราะคะแนนอาจมีการแก้ไขหรืออัปเดตได้

# %% [markdown]
# 6.พิกัด GPS ของสถานที่สำคัญหรือจุดแลนด์มาร์กที่ตั้งอยู่กับที่

# %% [markdown]
# = ใช้ tuple เพราะพิกัดของสถานที่หนึ่งเป็นค่าคงที่ ไม่ควรแก้ไข
